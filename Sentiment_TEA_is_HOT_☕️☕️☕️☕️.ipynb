# %% [markdown]
# <a href="https://colab.research.google.com/github/CindyRe/AdvanceMarketingMertics/blob/main/Sentiment_TEA_is_HOT_%E2%98%95%EF%B8%8F%E2%98%95%EF%B8%8F%E2%98%95%EF%B8%8F%E2%98%95%EF%B8%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  https://www.nltk.org/howto/data.html   Website

# %%
import pandas as pd

df = pd.read_csv('/content/fashionnova_reviews_processed.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Reviewer Name         2349 non-null   object
#  1   Profile Link          2350 non-null   object
#  2   Country               2349 non-null   object
#  3   Public Review         2350 non-null   object
#  4   Review Date           2350 non-null   object
#  5   Rating                2350 non-null   object
#  6   Review Title          2350 non-null   object
#  7   Review Text           2350 non-null   object
#  8   Date of Experience    2350 non-null   object
#  9   Review Count_y        2349 non-null   float64
#  10  Gossip Status         2350 non-null   object
#  11  Year                  2350 non-null   int64
#  12  Review Year           2350 non-null   int64
#  13  Date Only_Experience  2350 non-null   object
#  14  Date Only_Review      2350 non-null   object
# ...

# %% [markdown]
# Column

# %%
df = df[['Review Title', 'Review Text', 'Reviewer Name']]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Review Title   2350 non-null   object
#  1   Review Text    2350 non-null   object
#  2   Reviewer Name  2349 non-null   object
# dtypes: object(3)
# memory usage: 55.2+ KB

# %%
# prompt: a model that look for negative words in  Review Text

import pandas as pd
# !pip install -q nltk
import nltk
nltk.download('vader_lexicon')

from nltk.sentiment.vader import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

def analyze_sentiment(text):
  if pd.isna(text):
    return 0 # Handle missing values
  scores = analyzer.polarity_scores(text)
  # We'll consider a text to have negative words if the compound score is less than 0
  return scores['compound']

# Ensure df is created before being used
df = pd.read_csv('/content/fashionnova_reviews_processed.csv')
df = df[['Review Title', 'Review Text', 'Reviewer Name']] # Re-apply the column selection


# Now apply sentiment analysis to the entire DataFrame
df['Sentiment_score'] = df['Review Text'].apply(analyze_sentiment)

# Filter for reviews with a negative sentiment score
negative_reviews = df[df['Sentiment_score'] < 0].copy()
df['Label'] = df['Sentiment_score'].apply(lambda x: 'negative' if x < 0 else 'positive')

# Display the resulting DataFrame containing negative reviews
print(negative_reviews)
df.head(5)
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#                                 Review Title  \
# 4                          False advertising
# 18    I ordered clothes August the 9th they…
# 24      I have ordered over $130 in clothing
# 25                     My order was canceled
# 27    It’s difficult to browse when every 2…
# ...                                      ...
# 2291   It offered a discount code for me to…
# 2300                    No problem ordering.
# 2309                          SCAM AND FRAUD
# 2339                Robotic customer service
# 2345        The discount code is tricky  it…
#
#                                             Review Text      Reviewer Name  \
# 4     Disappointing experience. You don’t live up to...     Rosalyn Cousar
# 18    I ordered clothes August the 9th they said the...             Gladys
# ...

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Review Title     2350 non-null   object
#  1   Review Text      2350 non-null   object
#  2   Reviewer Name    2349 non-null   object
#  3   Sentiment_score  2350 non-null   float64
#  4   Label            2350 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 91.9+ KB

# %%
df.head(5)
# Out:
#                           Review Title  \
# 0    I love ordering from fashion nova
# 1   Top tier content for fashion nova
# 2  Prices and quality of products are…
# 3               Great customer service
# 4                    False advertising
#
#                                          Review Text    Reviewer Name  \
# 0  I love ordering from fashion nova. The clothes...        Champagne
# 1  Always amazing clothes and the fast shipping i...      Vg customer
# 2  Prices and quality of products are GREAT Would...  Colleen Burgher
# 3  Great customer service. I was helped until the...            R.G.M
# 4  Disappointing experience. You don’t live up to...   Rosalyn Cousar
#
#    Sentiment_score     Label
# 0           0.9509  positive
# 1           0.8884  positive
# 2           0.8279  positive
# 3           0.9610  positive
# 4          -0.7717  negative

# %%
# prompt: export to csv

negative_reviews.to_csv('Sentiment_reviews.csv', index=False)
